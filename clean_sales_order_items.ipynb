# %% [markdown]
# DATA QUALITY ASSESSMENT
# 1. Uniqueness
# 2. Completeness
#     a. seluruh value pada kolom OPITEMPOS null
# 3. Consistency
#     a. penulisan nama kolom masih dalam huruf kapital dan tidak ada spacing (_)
#     b. delivery_date masih dalam bentuk format integer
#     c. order_id masih dalam bentuk format integer
# 4. Validity
#     a. terdapat data outliers pada kolom delivery_date dengan jumlah 3 total order_id (500000112, 500000164, 500000308)

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text

# %%
sales_order_items = pd.read_csv("/Users/anyndaputri/Documents/Business Intelligence Binar/Challenge Platinum/Datasets SAP Bike Sales/SalesOrderItems.csv")

# %%
sales_order_items
# Out:
#       SALESORDERID  SALESORDERITEM PRODUCTID NOTEID CURRENCY  GROSSAMOUNT  \
# 0        500000000              10   MB-1034             USD         2499
# 1        500000000              20   CB-1161             USD          399
# 2        500000001              10   HB-1175             USD          899
# 3        500000001              20   RC-1056             USD         2499
# 4        500000001              30   CC-1021             USD         1144
# ...            ...             ...       ...    ...      ...          ...
# 1925     500000333              10   MB-1031             USD          649
# 1926     500000333              20   BX-1013             USD          449
# 1927     500000333              30   EB-1132             USD         1900
# 1928     500000333              40   BX-1011             USD          249
# 1929     500000333              50   BX-1015             USD          299
#
#       NETAMOUNT  TAXAMOUNT ITEMATPSTATUS  OPITEMPOS  QUANTITY QUANTITYUNIT  \
# ...

# %% [markdown]
# UNIQUENESS

# %%
sales_order_items.duplicated().sum() # tidak ada row yang duplikat
# Out:
# 0

# %% [markdown]
# COMPLETENESS

# %%
sales_order_items.info() # kolom OPITEMPOS null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SALESORDERID    1930 non-null   int64
#  1   SALESORDERITEM  1930 non-null   int64
#  2   PRODUCTID       1930 non-null   object
#  3   NOTEID          1930 non-null   object
#  4   CURRENCY        1930 non-null   object
#  5   GROSSAMOUNT     1930 non-null   int64
#  6   NETAMOUNT       1930 non-null   float64
#  7   TAXAMOUNT       1930 non-null   float64
#  8   ITEMATPSTATUS   1930 non-null   object
#  9   OPITEMPOS       0 non-null      float64
#  10  QUANTITY        1930 non-null   int64
#  11  QUANTITYUNIT    1930 non-null   object
#  12  DELIVERYDATE    1930 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 196.1+ KB

# %% [markdown]
# CONSISTENCY

# %%
sales_order_items.columns # penulisan nama kolom masih dalam huruf kapital dan tidak ada spacing (_)
# Out:
# Index(['SALESORDERID', 'SALESORDERITEM', 'PRODUCTID', 'NOTEID', 'CURRENCY',
#        'GROSSAMOUNT', 'NETAMOUNT', 'TAXAMOUNT', 'ITEMATPSTATUS', 'OPITEMPOS',
#        'QUANTITY', 'QUANTITYUNIT', 'DELIVERYDATE'],
#       dtype='object')

# %%
sales_order_items.columns = sales_order_items.columns.str.lower()

# %%
sales_order_items = sales_order_items.rename(columns={"salesorderid": "order_id", "salesorderitem": "sales_order_item", "productid": "product_id", "noteid": "note_id", 
                        "grossamount": "gross_amount", "netamount": "net_amount", "taxamount": "tax_amount", "itematpstatus": "item_atp_status", "opitempos": "op_item_pos",
                        "quantityunit": "quantity_unit", "deliverydate": "delivery_date"})

# %%
sales_order_items
# Out:
#        order_id  sales_order_item product_id note_id currency  gross_amount  \
# 0     500000000                10    MB-1034              USD          2499
# 1     500000000                20    CB-1161              USD           399
# 2     500000001                10    HB-1175              USD           899
# 3     500000001                20    RC-1056              USD          2499
# 4     500000001                30    CC-1021              USD          1144
# ...         ...               ...        ...     ...      ...           ...
# 1925  500000333                10    MB-1031              USD           649
# 1926  500000333                20    BX-1013              USD           449
# 1927  500000333                30    EB-1132              USD          1900
# 1928  500000333                40    BX-1011              USD           249
# 1929  500000333                50    BX-1015              USD           299
#
# ...

# %%
# membuat function untuk merubah format tanggal dari integer ke timestamp
def format_timestamp(date):
    string_date = str(date)
    year, month, day = string_date[0:4], string_date[4:6], string_date[6:8]
    date_format = f"{year}-{month}-{day}"
    timestamp = pd.Timestamp(date_format)
    return timestamp

# %%
sales_order_items["delivery_date"] = sales_order_items["delivery_date"].apply(format_timestamp)

# %%
sales_order_items[["order_id", "currency"]].groupby(by="currency").nunique() # currency sudah konsisten
# Out:
#           order_id
# currency
# USD            334

# %%
sales_order_items[["order_id", "quantity_unit"]].groupby(by="quantity_unit").nunique() # quantity_unit sudah konsisten
# Out:
#                order_id
# quantity_unit
# EA                  334

# %%
list(sales_order_items["product_id"]) # penulisan product_id sudah konsisten
# Out:
# ['MB-1034',
#  'CB-1161',
#  'HB-1175',
#  'RC-1056',
#  'CC-1021',
#  'CB-1161',
#  'HB-1175',
#  'RC-1055',
#  'DB-1081',
#  'EB-1133',
#  'BX-1015',
#  'CC-1021',
#  'RC-1056',
#  'BX-1013',
#  'RC-1056',
#  'CB-1161',
#  'EB-1131',
#  'MB-1034',
#  'DB-1082',
#  'EB-1134',
#  'BX-1014',
#  'EB-1134',
#  'CB-1163',
#  'BX-1013',
#  'MB-1034',
#  'MB-1031',
#  'RC-1051',
#  'HB-1174',
#  'RC-1054',
#  'CC-1021',
#  'RC-1052',
#  'BX-1011',
#  'HB-1175',
#  'RO-1002',
#  'EB-1137',
#  'CB-1163',
#  'EB-1134',
#  'HB-1176',
#  'RC-1052',
#  'EB-1135',
#  'RC-1054',
#  'HB-1171',
#  'EB-1137',
#  'CC-1022',
#  'CC-1023',
#  'RC-1052',
#  'BX-1014',
#  'EB-1131',
#  'EB-1135',
#  'CC-1021',
#  'EB-1135',
#  'BX-1013',
#  'DB-1081',
#  'CB-1161',
#  'HB-1171',
#  'HB-1175',
#  'RO-1002',
#  'CC-1021',
#  'MB-1032',
#  'RO-1001',
#  'MB-1031',
#  'BX-1016',
#  'EB-1132',
#  'EB-1135',
#  'RC-1054',
#  'HB-1176',
#  'CB-1161',
#  'BX-1013',
#  'RO-1001',
#  'BX-1015',
#  'RC-1055',
# ...

# %%
sales_order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1930 non-null   int64
#  1   sales_order_item  1930 non-null   int64
#  2   product_id        1930 non-null   object
#  3   note_id           1930 non-null   object
#  4   currency          1930 non-null   object
#  5   gross_amount      1930 non-null   int64
#  6   net_amount        1930 non-null   float64
#  7   tax_amount        1930 non-null   float64
#  8   item_atp_status   1930 non-null   object
#  9   op_item_pos       0 non-null      float64
#  10  quantity          1930 non-null   int64
#  11  quantity_unit     1930 non-null   object
#  12  delivery_date     1930 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 196.1+ KB

# %%
sales_order_items["order_id"] = sales_order_items["order_id"].astype(str)

# %%
sales_order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1930 non-null   object
#  1   sales_order_item  1930 non-null   int64
#  2   product_id        1930 non-null   object
#  3   note_id           1930 non-null   object
#  4   currency          1930 non-null   object
#  5   gross_amount      1930 non-null   int64
#  6   net_amount        1930 non-null   float64
#  7   tax_amount        1930 non-null   float64
#  8   item_atp_status   1930 non-null   object
#  9   op_item_pos       0 non-null      float64
#  10  quantity          1930 non-null   int64
#  11  quantity_unit     1930 non-null   object
#  12  delivery_date     1930 non-null   object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 196.1+ KB

# %% [markdown]
# VALIDITY

# %%
sales_order_items.describe([.25, .50, .75, .90, 1])
# Out:
#        sales_order_item  gross_amount   net_amount   tax_amount  op_item_pos  \
# count       1930.000000   1930.000000  1930.000000  1930.000000          0.0
# mean          40.880829   1909.601554  1670.901360   238.700194          NaN
# std           24.880248   1838.714628  1608.875299   229.839328          NaN
# min           10.000000    249.000000   217.875000    31.125000          NaN
# 25%           20.000000    525.000000   459.375000    65.625000          NaN
# 50%           40.000000   1200.000000  1050.000000   150.000000          NaN
# 75%           60.000000   2499.000000  2186.625000   312.375000          NaN
# 90%           80.000000   4800.000000  4200.000000   600.000000          NaN
# 100%         100.000000   7900.000000  6912.500000   987.500000          NaN
# max          100.000000   7900.000000  6912.500000   987.500000          NaN
#
#           quantity
# count  1930.000000
# mean      5.524870
# std       2.881926
# min       1.000000
# 25%       3.000000
# ...

# %%
sales_order_items[sales_order_items["delivery_date"] > pd.Timestamp('2020-01-01')] # terdapat data outliers pada delivery_date
# 3 total order_id (500000112, 500000164, 500000308)
# jika dijumlahkan data tersebut berdasarkan jumlah order dan net_amount, masih di bawah 5%, sehingga data bisa ditake out
# Out:
#        order_id  sales_order_item product_id note_id currency  gross_amount  \
# 618   500000112                10    HB-1173              USD           649
# 619   500000112                20    DB-1082              USD          1250
# 620   500000112                30    BX-1013              USD           449
# 621   500000112                40    DB-1082              USD          1250
# 622   500000112                50    RC-1054              USD          5499
# 623   500000112                60    MB-1033              USD          3999
# 624   500000112                70    CB-1163              USD           288
# 625   500000112                80    EB-1134              USD          4800
# 626   500000112                90    CC-1023              USD          1361
# 627   500000112               100    CB-1163              USD           288
# 933   500000164                10    RC-1055              USD          1999
# ...

# %%
sales_order_items_clean = sales_order_items[sales_order_items["delivery_date"] < pd.Timestamp('2020-01-01')]

# %% [markdown]
# EXTRACT TO POSTGRESQL

# %%
# extract dari database
engine = create_engine("postgresql://postgres:260399@localhost:5432/postgres")
connection = engine.connect()

# %%
sales_order_items_clean.to_sql("order_details_clean",
                                 con=connection,
                                 schema="base_plat_sap_bikes",
                                 if_exists="replace",
                                 index=True,
                                 method="multi"
)
# Out:
# 1908

# %%
# setting up the primary key
query_pk = """
alter table base_plat_sap_bikes.order_details_clean
add primary key(index)
"""
result = connection.execute(text(query_pk))
connection.commit()
connection.close()

# %%
# extract dari database
engine = create_engine("postgresql://postgres:260399@localhost:5432/postgres")
connection = engine.connect()

# %%
# setting up the foreign key
query_fk = ["alter table base_plat_sap_bikes.order_details_clean add constraint salesdet_cons foreign key(order_id) references base_plat_sap_bikes.sales_orders_clean(order_id)",
            "alter table base_plat_sap_bikes.order_details_clean add constraint proddet_cons foreign key(product_id) references base_plat_sap_bikes.products_clean(product_id)"
            ]
for q in query_fk:
    result = connection.execute(text(q))
connection.commit()
connection.close()
